# %%
class IITM:
    def into():
        print('hello buddy!!,how are you')

        def say_hello():
            print('hello')

            def bye():
                print('bye')

# %%
ayan = IITM()
print(type(ayan))
# Out:
# <class '__main__.IITM'>

# %%
class Remote:
    def __init__(self):
        print('object created with remote class')
        print('now you can use it')
        
    def volume_up(self):
      print('volume up by 1 unit')
        
    def volume_down(self):
        print('volume down by 1 unit')
        
    def power_on(self):
        print('tv is on')
        
    def power_off(self):
        print('tv is off')

    def auto_suggest_channel(self):
        import time
        print('searching trending channel')
        time.sleep(3)
        print('youtube!! IITM')

    def __del__(self):
        print('object has been successfully destroyed')

# %%
mi= Remote()
print('done')
# Out:
# object created with remote class
# now you can use it
# done

# %%
mi.power_off()
# Out:
# tv is off

# %%
mi.auto_suggest_channel()
# Out:
# searching trending channel
# youtube!! IITM

# %%
mi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 mi
#
# NameError: name 'mi' is not defined

# %%
class Car:
        def __init__(self):
            color='black'
            wheel=4
            spare_wheel=1
            airbag_support = True
            fuel_type = 'petrol'
            car_type = 'sadan'
            gear_type = ' Automatic'
    
        def auto_park(self):
                import IPython
                url = '''https://media.tenor.com/hk6K85f2yX0AAAAM/baddriver-parking.gif'''
                display(IPython.display.Image(url))

        def engine_on(self):
            import pygame
            pygame.init()
            path = r'''C:\Users\RACHIT SPARSH\Downloads\car-engine-372477.mp3'''
            music = pygame.mixer.Sound(path)
            music.play()
   
        def speed_up(self):
                c=10
                while 10<=200:
                    print(f'speed is increasing by {c} km/hr')
                    c+=10
                    display(clear=true)
                    time.sleep(0.5)
                    if c >=100:
                        print('you are crossing speed limit')
                        break
    
        def drift_brake(self,drift = False):
            if drift == True:
                import pygame
                pygame.init()
                path = r''' C:\Users\RACHIT SPARSH\Downloads\-110063.mp3'''
                music = pygame.mixer.Sound(path)
                music.play()
                import IPython
                url = '''https://i.pinimg.com/originals/97/90/a1/9790a1bdb56dfe6ed03d2b0ee32772ce.gif'''
                display(IPython.display.Image(url))

            else:
                print('brakes applied')

# %%
bmw = Car()

# %%
bmw.engine_on()

# %%
# pip install pygame

# %%
bmw.drift_brake()
# Out:
# brakes applied

# %%
 #pip install IPython

# %%
bmw.auto_park()

# %%
bmw.drift_brake()
# Out:
# brakes applied

# %%
bmw.

# %%
bmw.engine_on()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 bmw.engine_on()
#
# Cell In[70], line 17, in Car.engine_on(self)
#      16 def engine_on(self):
# ---> 17     import pygame
#      18     pygame.init()
#      19     path = r'''C:\Users\RACHIT SPARSH\Downloads\car-sound-effect-126709.mp'''
#
# ModuleNotFoundError: No module named 'pygame'

# %%
pip install pygame

# %%
# python to mysql connect

# %%
# pip install PyMySQL
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql as py
print('done')
# Out:
# done

# %%
conn=py.connect(user='root',
           password='Rachit123#',
          host='localhost',
          autocommit=True)
print('connection created successfully!!')
# Out:
# connection created successfully!!

# %%
#cursor

# %%
cur=conn.cursor()
print('done')
# Out:
# done

# %%
query= '''create database IITM_day5;'''

cur.execute(query)
print('done')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[13], line 3
#       1 query= '''create database IITM_day5;'''
# ----> 3 cur.execute(query)
#       4 print('done')
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
# ...

# %%
query = 'USE IITM_day5;'
cur.execute(query)
print('done')
# Out:
# done

# %%
query= '''create table students_details
(
SID int not null,
student_name varchar(50),
course varchar(50),
address varchar(50),
scholarship float
);'''
cur.execute(query)
print('done')
# Out:
# done

# %%
query = '''insert into students_details
values 
(101," mohan sharma","bca","delhi",5000),
(105," ravi sharma","mca","noida",15000);
'''
cur.execute(query)
print('done')
# Out:
# done

# %%
n=3
for i in range(n):
    sid = int ( input('enter roll number/sid;'))
    name = input('enter your name:')
    course = input('enter your course:')
    address = input('enter your address:')
    scholarship = float(input('enter your scholarship in rupees:'))
    q = f'''insert into students_details values
    ({sid},"{name}","{course}","{address}",{scholarship});'''
    cur.execute(q)
    print('record inserted successfully!!')
print('done')
# Out:
# enter roll number/sid; 101
# enter roll number/sid; 102
# enter roll number/sid; 103
# enter your name: sam
# enter your course: bca
# enter your address: delhi
# enter your scholarship in rupees: 5000
# record inserted successfully!!
# done

# %%
query = ''' select * from students_details;'''
cur.execute(query)



records = cur.fetchall()

all_columns = []
for i in cur.description:
    all_columns.append(i[0])


import pandas as pd
pd.DataFrame(records,columns=all_columns)
# Out:
#    SID   student_name course address  scholarship
# 0  101   mohan sharma    bca   delhi       5000.0
# 1  105    ravi sharma    mca   noida      15000.0
# 2  103          jatin    bca   delhi       1000.0
# 3  100            sam    bca   delhi        400.0
# 4   99          rohan   bcom   noida        500.0
# 5  103            sam    bca   delhi       5000.0

# %%
def show_records(db,table):
    query = f''' select * from {db}.{table};'''
    cur.execute(query)
    
    
    
    records = cur.fetchall()
    
    all_columns = []
    for i in cur.description:
        all_columns.append(i[0])
    
    
    import pandas as pd
    df= pd.DataFrame(records,columns=all_columns)
    return df

# %%
show_records('iitm_day5','students_details')
# Out:
#    SID   student_name course address  scholarship
# 0  101   mohan sharma    bca   delhi       5000.0
# 1  105    ravi sharma    mca   noida      15000.0
# 2  103          jatin    bca   delhi       1000.0
# 3  100            sam    bca   delhi        400.0
# 4   99          rohan   bcom   noida        500.0
# 5  103            sam    bca   delhi       5000.0

# %%
show_records('iitm_db','sample_superstore')
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9689    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9690    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9691    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9692    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9693    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...
